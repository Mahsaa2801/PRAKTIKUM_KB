# %% [markdown]
# ### Import Library

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_csv('Downloads/master.csv')

# %% [markdown]
# ### Melihat Dataset

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %% [markdown]
# ### GRAFIK BATANG

# %%
generasi = df["generation"].value_counts()
plt.bar(generasi.index, generasi, color = ["darkblue", "darkgreen","red","yellow","magenta","lightblue"])
plt.xlabel("Generasi", fontweight = "bold")
plt.ylabel("Jumlah", fontweight = "bold")
plt.title("Grafik Perbandingan Generasi", fontsize = 15, fontweight = "bold")
plt.xticks(rotation=60, ha='right')
plt.show()

# %%
generasi
# Out:
# Generation X       6408
# Silent             6364
# Millenials         5844
# Boomers            4990
# G.I. Generation    2744
# Generation Z       1470
# Name: generation, dtype: int64

# %% [markdown]
# #### Dari grafik batang di atas dapat di ketahui:
# #### - Kasus bunuh diri paling banyak di lakukan oleh Generation X (individu yang lahir di antara tahun 1965-1976) sebanyak 6408 kasus
# #### - Kasus bunuh diri terendah ada di Generation Z (individu yang lahir di tahun 1995-2012) yaitu sebanyak 1470 kasus

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(df.corr(),
            annot = True)
plt.title("Heatmap", fontsize = 20)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
df.plot.scatter("suicides_no", "year")
plt.title('Scatter Plot Relasi Antara Jumlah Bunuh diri dan Tahun terjadinya') 
print(df.corr())
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
#                         year  suicides_no  population  suicides/100k pop  \
# year                1.000000    -0.004546    0.008850          -0.039037
# suicides_no        -0.004546     1.000000    0.616162           0.306604
# population          0.008850     0.616162    1.000000           0.008285
# suicides/100k pop  -0.039037     0.306604    0.008285           1.000000
# HDI for year        0.366786     0.151399    0.102943           0.074279
# gdp_per_capita ($)  0.339134     0.061330    0.081510           0.001785
#
#                     HDI for year  gdp_per_capita ($)
# year                    0.366786            0.339134
# suicides_no             0.151399            0.061330
# population              0.102943            0.081510
# ...

# %% [markdown]
# #### Dari grafik di atas dapat diketahui bahwa pada rentang tahun 1990 - 2005 terjadi peningkatan kasus bunuh diri

# %% [markdown]
# ### Pie Chart

# %%
labels = ['Male', 'Female']
plt.pie(df['sex'].value_counts(), labels=labels, autopct="%1.1f%%") 
plt.title('Jenis Kelamin') 
plt.show()

# %% [markdown]
# #### Dari grafik di atas di ketahui jumlah pria dan wanita dalam kasus bunuh diri adalah sama
